# %% [markdown]
# <h1>COVID-19 Stats</h1>

# %% [markdown]
# Import components

# %%
from dataloader import loadAll
import ratings as rt

# %% [markdown]
# <hr>
# Load data

# %%
data = loadAll(doUpdateGit=True)
# Out:
# Updating git repository: Data/cases...
# Your branch is up to date with 'origin/master'.
# Already on 'master'
# Updating 6c4ac9ee..708bf215
# Fast-forward
# csse_covid_19_data/README.md                       |   47 +-
# csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv   |    6 +
# .../csse_covid_19_daily_reports/04-18-2020.csv     |    2 +-
# .../csse_covid_19_daily_reports/04-19-2020.csv     | 3073 +++++++++
# .../csse_covid_19_time_series/Errata.csv           |    2 +
# .../csse_covid_19_time_series/README.md            |   23 +-
# .../time_series_covid19_confirmed_US.csv           | 6518 ++++++++++----------
# .../time_series_covid19_confirmed_global.csv       |  530 +-
# .../time_series_covid19_deaths_US.csv              | 6518 ++++++++++----------
# .../time_series_covid19_deaths_global.csv          |  530 +-
# .../time_series_covid19_recovered_global.csv       |  502 +-
# 11 files changed, 10426 insertions(+), 7325 deletions(-)
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/04-19-2020.csv
# From https://github.com/CSSEGISandData/COVID-19
# 6c4ac9ee..708bf215  master     -> origin/master
# 23c819da..0dfbf910  web-data   -> origin/web-data
# Repository updated.
# Loading data...
# Loaded

# %% [markdown]
# <hr>
# <h2>Ratings</h2>
#
# Summarize for today

# %%
today = rt.mergeForDate(data)

# %% [markdown]
# Draw rating graphs:

# %%
rt.showRating(today, 10, 'cases')
rt.showRating(today, 10, 'cases', relTo='pop')
rt.showRating(today, 10, 'deaths', relTo='recovered')

# %% [markdown]
# <hr>
# <h2>Timeline stats</h2>
#
# Params and load:

# %%
startingDate = '3/1/20'
countries=['Russia', 'Italy', 'Spain', 'US', 'Germany']
data = rt.mergeForCountriesList(data, names=countries, starting_date=startingDate)

# %% [markdown]
# Draaw Timeline graphs:

# %%
rt.paintList(data, 'dCasesSmoothed', relToCases=False)
rt.paintList(data, 'dDeathsSmoothed', relToCases=False)
rt.paintList(data, 'deathsPerPopSmoothed', relToCases=True)

# %% [markdown]
# <h2>That's it</h2>
# Feel free to experiment with graph drawers parameters
