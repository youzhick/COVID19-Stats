# %% [markdown]
# <h1>COVID-19 Stats</h1>

# %% [markdown]
# Import components

# %%
from dataloader import loadAll
import ratings as rt

# %% [markdown]
# <hr>
# Load data

# %%
data = loadAll(doUpdateGit=True)
# Out:
# Updating git repository: Data/cases...
# Your branch is up to date with 'origin/master'.
# Already on 'master'
# Updating a74024c6..d2588311
# Fast-forward
# README.md                                          |    1 +
# csse_covid_19_data/README.md                       |    2 +
# .../csse_covid_19_daily_reports/06-18-2020.csv     | 7498 +++++++++----------
# .../csse_covid_19_daily_reports/06-19-2020.csv     | 7500 ++++++++++----------
# .../csse_covid_19_daily_reports/06-20-2020.csv     | 3754 ++++++++++
# .../csse_covid_19_daily_reports/06-21-2020.csv     | 3754 ++++++++++
# .../csse_covid_19_daily_reports/06-22-2020.csv     | 3757 ++++++++++
# .../csse_covid_19_daily_reports_us/06-18-2020.csv  |  118 +-
# .../csse_covid_19_daily_reports_us/06-19-2020.csv  |  118 +-
# .../csse_covid_19_daily_reports_us/06-20-2020.csv  |   59 +
# .../csse_covid_19_daily_reports_us/06-21-2020.csv  |   59 +
# .../csse_covid_19_daily_reports_us/06-22-2020.csv  |   59 +
# .../csse_covid_19_time_series/Errata.csv           |   11 +
# .../time_series_covid19_confirmed_US.csv           | 6524 ++++++++---------
# .../time_series_covid19_confirmed_global.csv       |  534 +-
# .../time_series_covid19_deaths_US.csv              | 6524 ++++++++---------
# .../time_series_covid19_deaths_global.csv          |  534 +-
# .../time_series_covid19_recovered_global.csv       |  508 +-
# 18 files changed, 26385 insertions(+), 14929 deletions(-)
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/06-20-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/06-21-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/06-22-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/06-20-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/06-21-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/06-22-2020.csv
# From https://github.com/CSSEGISandData/COVID-19
# a74024c6..d2588311  master                  -> origin/master
# * [new branch]        2732-Update-NC          -> origin/2732-Update-NC
# * [new branch]        2733-Update-Brazil-6-20 -> origin/2733-Update-Brazil-6-20
# 2a5f0f8c..2e182631  web-data                -> origin/web-data
# Repository updated.
# Loading data...
# Loaded

# %% [markdown]
# <hr>
# <h2>Ratings</h2>
#
# Summarize for today

# %%
today = rt.mergeForDate(data)

# %% [markdown]
# Draw rating graphs:

# %%
rt.showRating(today, 10, 'cases')
rt.showRating(today, 10, 'deaths')
rt.showRating(today, 10, 'cases', relTo='pop')
rt.showRating(today, 10, 'fatality')

# %% [markdown]
# <hr>
# <h2>Timeline stats</h2>
#
# Params and load:

# %%
startingDate = '3/1/20'
countries=['Russia', 'Italy', 'Spain', 'US', 'Germany', 'Brazil']
drawData = rt.mergeForCountriesList(data, names=countries, starting_date=startingDate)

# %% [markdown]
# Draw Timeline graphs:

# %%
rt.paintList(drawData, 'dCasesSmoothed', relToCases=False)
rt.paintList(drawData, 'activeCasesSmoothed', relToCases=False)
rt.paintList(drawData, 'dDeathsSmoothed', relToCases=False)
rt.paintList(drawData, 'deathsPerPopSmoothed', relToCases=True)
rt.paintList(drawData, 'dCasesSmoothed', relToCases=True)
rt.paintList(drawData, 'fatalitySmoothed', relToCases=False)

# %% [markdown]
# Some graphs for Europe solely, as US is too dominant in total numbers:

# %%
startingDate = '3/1/20'
countries=['Russia', 'Italy', 'Iran', 'Japan', 'Germany']
drawData = rt.mergeForCountriesList(data, names=countries, starting_date=startingDate)

rt.paintList(drawData, 'dCasesSmoothed', relToCases=False)
rt.paintList(drawData, 'activeCasesSmoothed', relToCases=False)
rt.paintList(drawData, 'dDeathsSmoothed', relToCases=False)
rt.paintList(drawData, 'deathsPerPopSmoothed', relToCases=True)
rt.paintList(drawData, 'dCasesSmoothed', relToCases=True)
rt.paintList(drawData, 'fatalitySmoothed', relToCases=False)

# %% [markdown]
# <h2>That's it</h2>
# Feel free to experiment with graph drawers parameters
