# %% [markdown]
# <h1>COVID-19 Stats</h1>

# %% [markdown]
# Import components

# %%
from dataloader import loadAll
import ratings as rt

# %% [markdown]
# <hr>
# Load data

# %%
data = loadAll(doUpdateGit=True)
# Out:
# Updating git repository: Data/cases...
# Your branch is up to date with 'origin/master'.
# Already on 'master'
# Updating 1a33be06..272b1eb8
# Fast-forward
# csse_covid_19_data/README.md                       |    3 +-
# csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv   |  111 +-
# .../csse_covid_19_daily_reports/05-21-2020.csv     | 3397 ++++++++++
# .../csse_covid_19_daily_reports/05-22-2020.csv     | 3404 ++++++++++
# .../csse_covid_19_daily_reports/05-23-2020.csv     | 3406 ++++++++++
# .../csse_covid_19_daily_reports_us/05-21-2020.csv  |   59 +
# .../csse_covid_19_daily_reports_us/05-22-2020.csv  |   59 +
# .../csse_covid_19_daily_reports_us/05-23-2020.csv  |   59 +
# .../csse_covid_19_time_series/Errata.csv           |    2 +
# .../time_series_covid19_confirmed_US.csv           | 6524 ++++++++++----------
# .../time_series_covid19_confirmed_global.csv       |  534 +-
# .../time_series_covid19_deaths_US.csv              | 6524 ++++++++++----------
# .../time_series_covid19_deaths_global.csv          |  534 +-
# .../time_series_covid19_recovered_global.csv       |  508 +-
# 14 files changed, 17781 insertions(+), 7343 deletions(-)
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/05-21-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/05-22-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/05-23-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/05-21-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/05-22-2020.csv
# create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports_us/05-23-2020.csv
# From https://github.com/CSSEGISandData/COVID-19
# 1a33be06..272b1eb8  master     -> origin/master
# 2dad99ea..814a0f77  web-data   -> origin/web-data
# Repository updated.
# Loading data...
# Loaded

# %% [markdown]
# <hr>
# <h2>Ratings</h2>
#
# Summarize for today

# %%
today = rt.mergeForDate(data)

# %% [markdown]
# Draw rating graphs:

# %%
rt.showRating(today, 10, 'cases')
rt.showRating(today, 10, 'deaths')
rt.showRating(today, 10, 'cases', relTo='pop')
rt.showRating(today, 10, 'fatality')

# %% [markdown]
# <hr>
# <h2>Timeline stats</h2>
#
# Params and load:

# %%
startingDate = '3/1/20'
countries=['Russia', 'Italy', 'Spain', 'US', 'Germany']
drawData = rt.mergeForCountriesList(data, names=countries, starting_date=startingDate)

# %% [markdown]
# Draw Timeline graphs:

# %%
rt.paintList(drawData, 'dCasesSmoothed', relToCases=False)
rt.paintList(drawData, 'dDeathsSmoothed', relToCases=False)
rt.paintList(drawData, 'deathsPerPopSmoothed', relToCases=True)
rt.paintList(drawData, 'dCasesSmoothed', relToCases=True)
rt.paintList(drawData, 'fatalitySmoothed', relToCases=False)

# %% [markdown]
# Some graphs for Europe solely, as US is too dominant in total numbers:

# %%
startingDate = '3/1/20'
countries=['Russia', 'Italy', 'Spain', 'Sweden', 'Belarus', 'Germany']
drawData = rt.mergeForCountriesList(data, names=countries, starting_date=startingDate)

rt.paintList(drawData, 'dCasesSmoothed', relToCases=False)
rt.paintList(drawData, 'dDeathsSmoothed', relToCases=False)
rt.paintList(drawData, 'deathsPerPopSmoothed', relToCases=True)
rt.paintList(drawData, 'dCasesSmoothed', relToCases=True)
rt.paintList(drawData, 'fatalitySmoothed', relToCases=False)

# %% [markdown]
# <h2>That's it</h2>
# Feel free to experiment with graph drawers parameters
